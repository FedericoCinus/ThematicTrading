# %% [markdown]
# # Pipeline checks
#
# One cell per stage, then the worked theme that crosses all of them.
# ✅ passes, 🔴 fails with the reason, · not written yet.

# %%
import sys
sys.path.insert(0, '.')
import checks

# %%
checks.imports()

# %%
checks.block('0_preprocessing')
# Out:
# 0_preprocessing
#    ✅  the steps collapse every message of one story, tomorrow's verbatim repeat included
#    ✅  the corpus keeps the words the wire published, prefixes and all
#    ✅  the corpus is [Headline, date] and sorted by date
#    ✅  a title published verbatim again is not a new story, so it is in the corpus exactly once

# %%
checks.block('1_detectors')
# Out:
# 1_detectors
#    ✅  strip_prefix drops a short wire prefix and leaves anything longer alone
#    ✅  strip_prefix also removes a real speaker, which is why it is not applied to the corpus
#    ✅  extract_terms returns sorted unigrams and bigrams, minus the stopwords
#    ✅  is_generic and is_event answer as their stopword lists say
#    ✅  the novelty gate lets `widget` through and never `acme`, which was always there
#    ✅  an anchor is promoted in at most one week — the week it emerged
#    ✅  themes, diagnostics and rejects are all keyed on `theme`, and the first two agree
#    ✅  a promoted anchor bridges: its partners are less connected than cluster_max allows
#    ✅  the case this detector solved in reality: `chatgpt` emerges in the week of 2023-01-02   [16s]

# %%
checks.block('2_monitors')

# %%
checks.block('3_baskets')

# %%
checks.block('3_baskets_filings')

# %%
checks.block('4_backtesting')

# %%
checks.block('artifacts')

# %%
checks.block('pipeline')
